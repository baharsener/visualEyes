# %% [markdown]
# I am trying the plotting function, along with edf reading and AOI defining functions on sample edf files from 2 studies. The first is an adult study run on EyeLink with PsychoPy. The second is an infant study, run with 6-month-old infants with EyeLink Experiment Builder. In both studies, participants view images presented on horizontally on the left, middle, and right side of the screen during the trials.

# %% [markdown]
# **Read and parse EDF**

# %%
import os
import eyelinkio
import numpy as np
import matplotlib.pyplot as plt
import numbers
import pandas as pd

#Load data
edf_path = '/Users/baharsener/visualEyes/data/TG_2015.edf'

#Read edf
edf = eyelinkio.read_edf(edf_path)
edf.keys()

#Get screen coordinates
screen_coordinates = edf['info']['screen_coords']
print(screen_coordinates)

#Convert edf to pandas df
df = edf.to_pandas()
samples = df['samples']
# Out:
# loadEvents = 1
# setTrial End:  END
# loadEvents = 1
# [1280 1024]

# %% [markdown]
# **AOI function**

# %%
def define_aoi(aoi_definitions):
    """
    Define Areas of Interest (AOIs).
    """
    aoi_boundaries = []

    for aoi in aoi_definitions:
        shape = aoi['shape'].lower()
        coordinates = aoi['coordinates']
        
        if shape == 'rectangle':
            x1, x2, y1, y2 = map(int, coordinates)
            # Add the rectangle's boundary as a list of (x, y) coordinates
            aoi_boundaries.append([(x1, y1), (x1, y2), (x2, y2), (x2, y1), (x1, y1)])
        elif shape == 'circle':
            x_center, y_center, radius = map(int, coordinates)
            # For circle, plot an outline by calculating points around the perimeter
            theta = np.linspace(0, 2 * np.pi, 100)
            x = x_center + radius * np.cos(theta)
            y = y_center + radius * np.sin(theta)
            aoi_boundaries.append(list(zip(x, y)))
        else:
            raise ValueError(f"Unsupported AOI shape: {shape}")
    
    return aoi_boundaries

# %% [markdown]
# **Gaze plotting with heatmap and AOI**

# %%
def plot_heatmap_with_aoi(data, screen_coords, aoi_definitions=None, bins=None):
    """
    Plots a heatmap of eye-tracking data and overlays AOIs if defined.

    Parameters:
    - data: DataFrame containing 'xpos' and 'ypos' for plotting.
    - screen_coords: Tuple of (screen_width, screen_height,).
    - aoi_definitions: List of dictionaries defining the AOIs (optional).
    - bins: Either an integer specifying the number of bins for both dimensions,
            or a tuple (bins_x, bins_y) for separate bin sizes.
    """
    # Filter NaN values in the gaze columns
    data = data.dropna(subset=['xpos', 'ypos'])

    # Get screen width and height
    screen_width, screen_height = screen_coords

    # Filter gaze data outside the screen coordinates
    data = data[(data['xpos'] >= 0) & (data['xpos'] <= screen_width) & 
            (data['ypos'] >= 0) & (data['ypos'] <= screen_height)]

    # Determine bins (depends a bit on screen)
    if bins is None:  # Default bins, 20 px bins here if nothing else is given
        bins_x = int(screen_width / 20)
        bins_y = int(screen_height / 20)
    elif isinstance(bins, int):  # User-defined, if bins for x and y are the same
        bins_x = bins_y = bins
    elif isinstance(bins, (tuple, list)) and len(bins) == 2:  # User-defined, if different bins for x and y are desired
        bins_x, bins_y = bins
    else:
        raise ValueError("`bins` must be an integer or a tuple of two integers.")

    heatmap, xedges, yedges = np.histogram2d(
    data['xpos'], data['ypos'], bins=[bins_x, bins_y]
)

    # Plot the heatmap:
    # When np.histogram2d is used, the output heatmap has rows corresponding to y bins and columns to x bins. 
    # However, in visualizations (like plt.imshow), the default orientation assumes rows correspond to x and columns to y. 
    # Transposing ensures that heatmap aligns with the correct visual representation.
    plt.imshow(heatmap.T, origin='lower', cmap='viridis', extent=[0, screen_width, 0, screen_height])
    plt.colorbar(label='Count')

    # Adjust x and y axis limits
    plt.xlim(0, screen_width)
    plt.ylim(0, screen_height)

    # If AOIs are defined, draw them
    if aoi_definitions:
        aoi_boundaries = define_aoi(aoi_definitions)
        for boundary in aoi_boundaries:
            # Outline the AOI by drawing its boundary
            boundary = np.array(boundary)
            plt.plot(boundary[:, 0], boundary[:, 1], color='red', lw=1)  # Red outline, line width = 1
    # Outline AOIs transposing has the same logic here: if the AOI definition matrix aligns with (row, column) as (y, x), 
    #transposing aligns it with the screen coordinates.

    # Invert y-axis to set (0, 0) at the top-left
    plt.gca().invert_yaxis() 

    # Add title and display the plot
    plt.title('Heatmap of Gaze Data')
    plt.xlabel('X Position (pixels)')
    plt.ylabel('Y Position (pixels)')
    plt.show()

# %% [markdown]
# **Plot adult data with the AOI's**

# %%
#Clear previous
plt.clf()
plt.close()

#Load data
edf_path = '/Users/baharsener/visualEyes/data/TG_2015.edf'

#Read edf
edf = eyelinkio.read_edf(edf_path)
edf.keys()

#Get screen coordinates
screen_coordinates = edf['info']['screen_coords']
print(screen_coordinates)

#Convert edf to pandas df
df = edf.to_pandas()
print(type(df['samples'])) 
print(df['samples'].head())

#Define an AOI
screen_width, screen_height = screen_coordinates
aoi_definitions = [{'shape': 'rectangle', 'coordinates': (550, 750, 350, 550)},
                   { "shape": "circle", "coordinates": [150, 400, 100]}]

#Gaze data (just x and y)
data = df['samples'][['xpos', 'ypos']]

#Plot
plot_heatmap_with_aoi(data, screen_coordinates, aoi_definitions)
# Out:
# loadEvents = 1
# setTrial End:  END
# loadEvents = 1
# [1280 1024]
# <class 'pandas.core.frame.DataFrame'>
#          xpos        ypos     ps
# 0  599.200012  452.500000  510.0
# 1  599.500000  454.200012  511.0
# 2  600.000000  455.899994  511.0
# 3  600.400024  457.299988  512.0
# 4  600.700012  459.100006  513.0

# %% [markdown]
# **Now with infant data, without an AOI (infants are not presented with a fixation cross because we cannot instruct them to look at it)**

# %%
#Clear previous
plt.clf()
plt.close()

#Load data
edf_path = '/Users/baharsener/Desktop/BMG_1122.edf'

#Read edf
edf = eyelinkio.read_edf(edf_path)

#Get dataframe
#Convert edf to pandas df
df = edf.to_pandas()
samples = df['samples']

#Get screen coordinates
screen_coordinates = edf['info']['screen_coords']

df = pd.DataFrame(edf['samples'].T, columns=['xpos', 'ypos', 'pupil_area'])

#Gaze data (just x and y)
data = df.dropna(subset=['xpos', 'ypos'])

#Plot
aoi_definitions = None
plot_heatmap_with_aoi(data, screen_coordinates, aoi_definitions)
# Out:
# loadEvents = 1
# Missing 1 samples. Inserting dummy samples
# Missing (3337940-3337943) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3338072-3338075) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3340772-3340775) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3340936-3340939) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3341018-3341021) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352784-3352787) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352826-3352829) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352914-3352917) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3360700-3360703) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3361278-3361281) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365008-3365011) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365094-3365097) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365298-3365301) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365486-3365489) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365762-3365765) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3371332-3371335) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3371880-3371883) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3373264-3373267) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3380162-3380165) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3383848-3383851) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384112-3384115) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384274-3384277) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384548-3384551) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384802-3384805) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3406980-3406983) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3407020-3407023) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3407082-3407085) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3409868-3409871) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3447718-3447721) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3451202-3451205) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3451372-3451375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3453900-3453903) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3458188-3458191) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3458722-3458725) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3463878-3463881) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3464372-3464375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3467542-3467545) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3467754-3467757) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3475216-3475219) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3484618-3484621) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3489818-3489821) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3489950-3489953) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3495148-3495151) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3495492-3495495) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3501758-3501761) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3502250-3502253) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3510142-3510145) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3513636-3513639) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3514062-3514065) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3514560-3514563) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3516664-3516667) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3516702-3516705) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3517304-3517307) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3521556-3521559) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3521684-3521687) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3527962-3527965) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3528024-3528027) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3529038-3529041) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3530638-3530641) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532316-3532319) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532354-3532357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532392-3532395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532676-3532679) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543318-3543321) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543354-3543357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543406-3543409) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3544376-3544379) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3559900-3559903) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3560434-3560437) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3571760-3571763) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3571840-3571843) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3572528-3572531) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3580280-3580283) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3583660-3583663) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3583702-3583705) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3584048-3584051) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3604288-3604291) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3612558-3612561) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3613796-3613799) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3613896-3613899) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3614022-3614025) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3614168-3614171) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3625746-3625749) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3626246-3626249) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3631522-3631525) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645508-3645511) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645574-3645577) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645948-3645951) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3646400-3646403) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3646668-3646671) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3647728-3647731) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3647938-3647941) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3649148-3649151) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3658222-3658225) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3658354-3658357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3665756-3665759) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672150-3672153) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672196-3672199) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672290-3672293) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3675484-3675487) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3680554-3680557) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3680680-3680683) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3681132-3681135) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688038-3688041) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688062-3688065) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688092-3688095) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688136-3688139) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3689372-3689375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3692972-3692975) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3693718-3693721) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3696392-3696395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3696956-3696959) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3700022-3700025) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3705392-3705395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3705780-3705783) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3712152-3712155) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3713664-3713667) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3713756-3713759) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3715784-3715787) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3717450-3717453) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3718102-3718105) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3718944-3718947) samples. Calculating speriod
# setTrial End:  END
# loadEvents = 1
# Missing 1 samples. Inserting dummy samples
# Missing (3337940-3337943) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3338072-3338075) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3340772-3340775) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3340936-3340939) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3341018-3341021) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352784-3352787) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352826-3352829) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3352914-3352917) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3360700-3360703) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3361278-3361281) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365008-3365011) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365094-3365097) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365298-3365301) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365486-3365489) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3365762-3365765) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3371332-3371335) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3371880-3371883) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3373264-3373267) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3380162-3380165) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3383848-3383851) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384112-3384115) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384274-3384277) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384548-3384551) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3384802-3384805) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3406980-3406983) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3407020-3407023) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3407082-3407085) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3409868-3409871) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3447718-3447721) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3451202-3451205) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3451372-3451375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3453900-3453903) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3458188-3458191) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3458722-3458725) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3463878-3463881) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3464372-3464375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3467542-3467545) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3467754-3467757) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3475216-3475219) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3484618-3484621) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3489818-3489821) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3489950-3489953) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3495148-3495151) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3495492-3495495) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3501758-3501761) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3502250-3502253) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3510142-3510145) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3513636-3513639) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3514062-3514065) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3514560-3514563) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3516664-3516667) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3516702-3516705) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3517304-3517307) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3521556-3521559) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3521684-3521687) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3527962-3527965) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3528024-3528027) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3529038-3529041) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3530638-3530641) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532316-3532319) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532354-3532357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532392-3532395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3532676-3532679) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543318-3543321) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543354-3543357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3543406-3543409) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3544376-3544379) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3559900-3559903) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3560434-3560437) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3571760-3571763) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3571840-3571843) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3572528-3572531) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3580280-3580283) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3583660-3583663) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3583702-3583705) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3584048-3584051) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3604288-3604291) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3612558-3612561) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3613796-3613799) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3613896-3613899) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3614022-3614025) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3614168-3614171) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3625746-3625749) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3626246-3626249) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3631522-3631525) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645508-3645511) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645574-3645577) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3645948-3645951) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3646400-3646403) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3646668-3646671) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3647728-3647731) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3647938-3647941) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3649148-3649151) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3658222-3658225) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3658354-3658357) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3665756-3665759) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672150-3672153) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672196-3672199) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3672290-3672293) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3675484-3675487) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3680554-3680557) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3680680-3680683) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3681132-3681135) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688038-3688041) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688062-3688065) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688092-3688095) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3688136-3688139) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3689372-3689375) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3692972-3692975) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3693718-3693721) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3696392-3696395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3696956-3696959) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3700022-3700025) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3705392-3705395) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3705780-3705783) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3712152-3712155) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3713664-3713667) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3713756-3713759) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3715784-3715787) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3717450-3717453) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3718102-3718105) samples. Calculating speriod
# Missing 1 samples. Inserting dummy samples
# Missing (3718944-3718947) samples. Calculating speriod
# [1024  768]
# <class 'pandas.core.frame.DataFrame'>
#    xpos  ypos   ps
# 0   NaN   NaN  0.0
# 1   NaN   NaN  0.0
# 2   NaN   NaN  0.0
# 3   NaN   NaN  0.0
# 4   NaN   NaN  0.0

# %% [markdown]
# You can see here how different adult and infant eye data can look! Adults were explicitly instructed to look to the fixation cross in the middle (where the AOI overlay is) and also instructed to look at the images, so we see the three clear locations in which the images appeared. This plot could tell us whether the participant is following instructions, and whether our calibration was good! With the infants, it is trickier, because we cannot explicitly instruct them. However, I can see that this infant was not reliably looking at all three images presented, and mostly only fixated on the right side of the screen, potentially due to one particular image being interesting, or because there was one trial for which they were more attentive. Because the overall pattern looks odd, I will do a deeper dive into understanding which trials this baby was attending to the screen.
