# %% [markdown]
# I am trying the plotting function, along with edf reading and AOI defining functions on sample edf files from 2 studies. The first is an adult study run on EyeLink with PsychoPy. The second is an infant study, run with 6-month-old infants with EyeLink Experiment Builder. In both studies, participants view images presented on horizontally on the left, middle, and right side of the screen during the trials.

# %% [markdown]
# **Read and parse EDF**

# %%
import os
import eyelinkio
import numpy as np
import matplotlib.pyplot as plt
import numbers
import pandas as pd

#Load data
edf_path = '/Users/baharsener/visualEyes/data/TG_2015.edf'

#Read edf
edf = eyelinkio.read_edf(edf_path)
edf.keys()

#Get screen coordinates
screen_coordinates = edf['info']['screen_coords']
print(screen_coordinates)

#Convert edf to pandas df
df = edf.to_pandas()
samples = df['samples']
# Out:
# loadEvents = 1
# setTrial End:  END
# loadEvents = 1
# [1280 1024]

# %%
#Clear previous
plt.clf()
plt.close()

#Load data
edf_path = '/Users/baharsener/visualEyes/data/TG_2015.edf'

#Read edf
edf = eyelinkio.read_edf(edf_path)
edf.keys()

#Get screen coordinates
screen_coordinates = edf['info']['screen_coords']
print(screen_coordinates)

#Convert edf to pandas df
df = edf.to_pandas()
print(type(df['samples'])) 

#Define an AOI
screen_width, screen_height = screen_coordinates
aoi_definitions = [{'shape': 'rectangle', 'coordinates': (550, 750, 350, 550)},
                   { "shape": "circle", "coordinates": [150, 400, 100]}]

#Gaze data (just x and y)
data = df['samples'][['xpos', 'ypos']]

#Plot
plot_heatmap(data, screen_coordinates, aoi_definitions)
# Out:
# loadEvents = 1
# setTrial End:  END
# loadEvents = 1
# [1280 1024]
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 29
#      26 data = df['samples'][['xpos', 'ypos']]
#      28 #Plot
# ---> 29 plot_heatmap(data, screen_coordinates, aoi_definitions)
#
# NameError: name 'plot_heatmap' is not defined

# %% [markdown]
# Adults were explicitly instructed to look to the fixation cross in the middle (where the AOI overlay is) and also instructed to look at the images, so we see the three clear locations in which the images appeared. This plot could tell us whether the participant is following instructions, and whether our calibration was good! For example, if the gaze data are clustering in locations the images typically do not appear, that could indicate poor calibration.
